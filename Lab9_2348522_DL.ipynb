# %% [markdown]
# <a href="https://colab.research.google.com/github/johnjustine5646/DL_Labs_Sem3/blob/main/Lab9_2348522_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
dataframe = pd.read_csv(url, usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %% [markdown]
# ## Normalize the dataset

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %% [markdown]
# ## Split into train and test sets

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(f'Train size: {train_size}, Test size: {test_size}')
# Out:
# Train size: 96, Test size: 48

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# ## LSTM Model

# %%
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 94/94 - 4s - loss: 0.0662 - 4s/epoch - 40ms/step
# Epoch 2/100
# 94/94 - 0s - loss: 0.0370 - 156ms/epoch - 2ms/step
# Epoch 3/100
# 94/94 - 0s - loss: 0.0267 - 152ms/epoch - 2ms/step
# Epoch 4/100
# 94/94 - 0s - loss: 0.0234 - 159ms/epoch - 2ms/step
# Epoch 5/100
# 94/94 - 0s - loss: 0.0221 - 151ms/epoch - 2ms/step
# Epoch 6/100
# 94/94 - 1s - loss: 0.0215 - 515ms/epoch - 5ms/step
# Epoch 7/100
# 94/94 - 0s - loss: 0.0210 - 156ms/epoch - 2ms/step
# Epoch 8/100
# 94/94 - 0s - loss: 0.0206 - 152ms/epoch - 2ms/step
# Epoch 9/100
# 94/94 - 0s - loss: 0.0202 - 167ms/epoch - 2ms/step
# Epoch 10/100
# 94/94 - 0s - loss: 0.0199 - 154ms/epoch - 2ms/step
# Epoch 11/100
# 94/94 - 0s - loss: 0.0195 - 156ms/epoch - 2ms/step
# Epoch 12/100
# 94/94 - 0s - loss: 0.0191 - 159ms/epoch - 2ms/step
# Epoch 13/100
# 94/94 - 0s - loss: 0.0189 - 144ms/epoch - 2ms/step
# Epoch 14/100
# 94/94 - 0s - loss: 0.0184 - 150ms/epoch - 2ms/step
# Epoch 15/100
# 94/94 - 0s - loss: 0.0182 - 147ms/epoch - 2ms/step
# Epoch 16/100
# 94/94 - 0s - loss: 0.0178 - 146ms/epoch - 2ms/step
# Epoch 17/100
# 94/94 - 0s - loss: 0.0176 - 168ms/epoch - 2ms/step
# Epoch 18/100
# 94/94 - 0s - loss: 0.0171 - 157ms/epoch - 2ms/step
# Epoch 19/100
# 94/94 - 0s - loss: 0.0166 - 154ms/epoch - 2ms/step
# Epoch 20/100
# 94/94 - 0s - loss: 0.0161 - 156ms/epoch - 2ms/step
# Epoch 21/100
# 94/94 - 0s - loss: 0.0155 - 152ms/epoch - 2ms/step
# Epoch 22/100
# 94/94 - 0s - loss: 0.0150 - 150ms/epoch - 2ms/step
# Epoch 23/100
# 94/94 - 0s - loss: 0.0142 - 156ms/epoch - 2ms/step
# Epoch 24/100
# 94/94 - 0s - loss: 0.0135 - 153ms/epoch - 2ms/step
# Epoch 25/100
# 94/94 - 0s - loss: 0.0128 - 165ms/epoch - 2ms/step
# Epoch 26/100
# 94/94 - 0s - loss: 0.0120 - 147ms/epoch - 2ms/step
# Epoch 27/100
# 94/94 - 0s - loss: 0.0108 - 153ms/epoch - 2ms/step
# Epoch 28/100
# 94/94 - 0s - loss: 0.0097 - 144ms/epoch - 2ms/step
# Epoch 29/100
# 94/94 - 0s - loss: 0.0085 - 153ms/epoch - 2ms/step
# Epoch 30/100
# 94/94 - 0s - loss: 0.0070 - 154ms/epoch - 2ms/step
# Epoch 31/100
# 94/94 - 0s - loss: 0.0058 - 163ms/epoch - 2ms/step
# Epoch 32/100
# 94/94 - 0s - loss: 0.0047 - 152ms/epoch - 2ms/step
# Epoch 33/100
# 94/94 - 0s - loss: 0.0037 - 151ms/epoch - 2ms/step
# Epoch 34/100
# 94/94 - 0s - loss: 0.0030 - 149ms/epoch - 2ms/step
# Epoch 35/100
# 94/94 - 0s - loss: 0.0026 - 151ms/epoch - 2ms/step
# Epoch 36/100
# 94/94 - 0s - loss: 0.0023 - 156ms/epoch - 2ms/step
# Epoch 37/100
# 94/94 - 0s - loss: 0.0023 - 158ms/epoch - 2ms/step
# Epoch 38/100
# 94/94 - 0s - loss: 0.0021 - 166ms/epoch - 2ms/step
# Epoch 39/100
# 94/94 - 0s - loss: 0.0021 - 154ms/epoch - 2ms/step
# Epoch 40/100
# 94/94 - 0s - loss: 0.0021 - 151ms/epoch - 2ms/step
# Epoch 41/100
# 94/94 - 0s - loss: 0.0020 - 146ms/epoch - 2ms/step
# Epoch 42/100
# 94/94 - 0s - loss: 0.0021 - 152ms/epoch - 2ms/step
# Epoch 43/100
# 94/94 - 0s - loss: 0.0021 - 211ms/epoch - 2ms/step
# Epoch 44/100
# 94/94 - 0s - loss: 0.0021 - 265ms/epoch - 3ms/step
# Epoch 45/100
# 94/94 - 0s - loss: 0.0021 - 225ms/epoch - 2ms/step
# Epoch 46/100
# 94/94 - 0s - loss: 0.0021 - 229ms/epoch - 2ms/step
# Epoch 47/100
# 94/94 - 0s - loss: 0.0021 - 214ms/epoch - 2ms/step
# Epoch 48/100
# 94/94 - 0s - loss: 0.0021 - 225ms/epoch - 2ms/step
# Epoch 49/100
# 94/94 - 0s - loss: 0.0020 - 229ms/epoch - 2ms/step
# Epoch 50/100
# 94/94 - 0s - loss: 0.0020 - 206ms/epoch - 2ms/step
# Epoch 51/100
# 94/94 - 0s - loss: 0.0020 - 222ms/epoch - 2ms/step
# Epoch 52/100
# 94/94 - 0s - loss: 0.0021 - 216ms/epoch - 2ms/step
# Epoch 53/100
# 94/94 - 0s - loss: 0.0021 - 237ms/epoch - 3ms/step
# Epoch 54/100
# 94/94 - 0s - loss: 0.0020 - 151ms/epoch - 2ms/step
# Epoch 55/100
# 94/94 - 0s - loss: 0.0021 - 150ms/epoch - 2ms/step
# Epoch 56/100
# 94/94 - 0s - loss: 0.0020 - 152ms/epoch - 2ms/step
# Epoch 57/100
# 94/94 - 0s - loss: 0.0020 - 153ms/epoch - 2ms/step
# Epoch 58/100
# 94/94 - 0s - loss: 0.0020 - 159ms/epoch - 2ms/step
# Epoch 59/100
# 94/94 - 0s - loss: 0.0020 - 147ms/epoch - 2ms/step
# Epoch 60/100
# 94/94 - 0s - loss: 0.0020 - 174ms/epoch - 2ms/step
# Epoch 61/100
# 94/94 - 0s - loss: 0.0020 - 151ms/epoch - 2ms/step
# Epoch 62/100
# 94/94 - 0s - loss: 0.0021 - 159ms/epoch - 2ms/step
# Epoch 63/100
# 94/94 - 0s - loss: 0.0020 - 153ms/epoch - 2ms/step
# Epoch 64/100
# 94/94 - 0s - loss: 0.0020 - 152ms/epoch - 2ms/step
# Epoch 65/100
# 94/94 - 0s - loss: 0.0021 - 146ms/epoch - 2ms/step
# Epoch 66/100
# 94/94 - 0s - loss: 0.0021 - 159ms/epoch - 2ms/step
# Epoch 67/100
# 94/94 - 0s - loss: 0.0021 - 147ms/epoch - 2ms/step
# Epoch 68/100
# 94/94 - 0s - loss: 0.0021 - 149ms/epoch - 2ms/step
# Epoch 69/100
# 94/94 - 0s - loss: 0.0021 - 151ms/epoch - 2ms/step
# Epoch 70/100
# 94/94 - 0s - loss: 0.0020 - 154ms/epoch - 2ms/step
# Epoch 71/100
# 94/94 - 0s - loss: 0.0021 - 145ms/epoch - 2ms/step
# Epoch 72/100
# 94/94 - 0s - loss: 0.0020 - 149ms/epoch - 2ms/step
# Epoch 73/100
# 94/94 - 0s - loss: 0.0020 - 156ms/epoch - 2ms/step
# Epoch 74/100
# 94/94 - 0s - loss: 0.0020 - 143ms/epoch - 2ms/step
# Epoch 75/100
# 94/94 - 0s - loss: 0.0020 - 149ms/epoch - 2ms/step
# Epoch 76/100
# 94/94 - 0s - loss: 0.0020 - 155ms/epoch - 2ms/step
# Epoch 77/100
# 94/94 - 0s - loss: 0.0020 - 151ms/epoch - 2ms/step
# Epoch 78/100
# 94/94 - 0s - loss: 0.0020 - 155ms/epoch - 2ms/step
# Epoch 79/100
# 94/94 - 0s - loss: 0.0021 - 153ms/epoch - 2ms/step
# Epoch 80/100
# 94/94 - 0s - loss: 0.0020 - 163ms/epoch - 2ms/step
# Epoch 81/100
# 94/94 - 0s - loss: 0.0021 - 155ms/epoch - 2ms/step
# Epoch 82/100
# 94/94 - 0s - loss: 0.0020 - 160ms/epoch - 2ms/step
# Epoch 83/100
# 94/94 - 0s - loss: 0.0020 - 154ms/epoch - 2ms/step
# Epoch 84/100
# 94/94 - 0s - loss: 0.0021 - 158ms/epoch - 2ms/step
# Epoch 85/100
# 94/94 - 0s - loss: 0.0020 - 163ms/epoch - 2ms/step
# Epoch 86/100
# 94/94 - 0s - loss: 0.0020 - 167ms/epoch - 2ms/step
# Epoch 87/100
# 94/94 - 0s - loss: 0.0020 - 159ms/epoch - 2ms/step
# Epoch 88/100
# 94/94 - 0s - loss: 0.0021 - 154ms/epoch - 2ms/step
# Epoch 89/100
# 94/94 - 0s - loss: 0.0020 - 159ms/epoch - 2ms/step
# Epoch 90/100
# 94/94 - 0s - loss: 0.0020 - 151ms/epoch - 2ms/step
# Epoch 91/100
# 94/94 - 0s - loss: 0.0020 - 156ms/epoch - 2ms/step
# Epoch 92/100
# 94/94 - 0s - loss: 0.0020 - 160ms/epoch - 2ms/step
# Epoch 93/100
# 94/94 - 0s - loss: 0.0020 - 152ms/epoch - 2ms/step
# Epoch 94/100
# 94/94 - 0s - loss: 0.0020 - 159ms/epoch - 2ms/step
# Epoch 95/100
# 94/94 - 0s - loss: 0.0021 - 153ms/epoch - 2ms/step
# Epoch 96/100
# 94/94 - 0s - loss: 0.0020 - 150ms/epoch - 2ms/step
# Epoch 97/100
# 94/94 - 0s - loss: 0.0021 - 148ms/epoch - 2ms/step
# Epoch 98/100
# 94/94 - 0s - loss: 0.0020 - 160ms/epoch - 2ms/step
# Epoch 99/100
# 94/94 - 0s - loss: 0.0020 - 163ms/epoch - 2ms/step
# Epoch 100/100
# 94/94 - 0s - loss: 0.0020 - 147ms/epoch - 2ms/step

# %% [markdown]
# ## Make Predictions

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print(f'Train Score: {trainScore:.2f} RMSE')
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print(f'Test Score: {testScore:.2f} RMSE')
# Out:
# 3/3 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 0s 6ms/step
# Train Score: 22.79 RMSE
# Test Score: 48.76 RMSE

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

plt.figure(figsize=(10, 6))
plt.plot(scaler.inverse_transform(dataset)[len(trainPredict)+(look_back*2)+1:len(dataset)-1], label='Actual')
plt.plot(testPredict, label='Predicted')
plt.title('Actual and Predicted Values')
plt.xlabel('Time')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
